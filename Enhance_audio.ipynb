# %%
from dataloading import ClarityAudioDataloaderSequenceAudio, ClarityAudioDataloaderSequenceSpectrograms
from pathlib import Path
import sklearn
import tensorflow as tf
import numpy as np
import IPython.display as ipd
import matplotlib.pyplot as plt
import librosa
import tqdm
from custom_unet import custom_unet
from pathlib import Path
import os
from IPython.display import clear_output

eps = 1e-9

# %%
fs = 8000

spec_frame_size = 512 # odd fft ensures even rfft 
spec_frame_step = spec_frame_size // 4 #int(fs * 5e-3) // 2

channels_in = 6
lookahead_frame_size = int(6.0*fs)
lookahead_frame_step = int(np.floor(5e-3 * fs))
batch_size = 3

# %%
data_loader = ClarityAudioDataloaderSequenceSpectrograms(
    spec_frame_step=spec_frame_step,
    spec_frame_size=spec_frame_size,
    frame_step=lookahead_frame_step,
    frame_size=lookahead_frame_size,
    new_sample_rate=fs,
    batch_size=batch_size,
    target_length=6.0*fs,
    verbose=0,
    return_type="abs",
    n_proc=8,
    subset_size_ratio=0.1
)

x_spec, y_spec = data_loader[0]
frames = x_spec.shape[1]
bins = x_spec.shape[2]
channels = x_spec.shape[3]
print(x_spec.shape)
# Out:
# (360, 376, 257, 6)

# %%
# enq = tf.keras.utils.OrderedEnqueuer(data_loader, use_multiprocessing=True)
# enq.start(workers=1)
# gen = enq.get()
# for i in range(30):
#     print(i)
#     next(gen)
#     print(f"outer {i}")
# enq.stop()
# print('test with', workers, 'workers took', datetime.datetime.now() - start)
# print("results:", results)

# %%
model = custom_unet(
    input_shape=(frames, bins, 6),
    input_type="mag",
    output_channels=1,
    activation="relu",
    use_batch_norm=True,
    upsample_mode="deconv",  # 'deconv' or 'simple'
    dropout=0.3,
    dropout_change_per_layer=0.0,
    dropout_type="spatial",
    use_dropout_on_upsampling=False,
    use_attention=True,
    filters=16,
    num_layers=4,
    mag_activation="relu",
    phase_activation=None,
)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 376, 257, 6) 0
# __________________________________________________________________________________________________
# tf.compat.v1.pad (TFOpLambda)   (None, 512, 512, 6)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 512, 512, 16) 864         tf.compat.v1.pad[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 512, 512, 16) 64          conv2d[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d (SpatialDropo (None, 512, 512, 16) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 512, 512, 16) 2304        spatial_dropout2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 512, 512, 16) 64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 256, 256, 16) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 256, 256, 32) 4608        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 256, 256, 32) 128         conv2d_2[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_1 (SpatialDro (None, 256, 256, 32) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 256, 256, 32) 9216        spatial_dropout2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 256, 256, 32) 128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 32) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 128, 128, 64) 18432       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 128, 128, 64) 256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_2 (SpatialDro (None, 128, 128, 64) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 128, 128, 64) 36864       spatial_dropout2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 128, 128, 64) 256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 64, 64, 128)  73728       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 64, 64, 128)  512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_3 (SpatialDro (None, 64, 64, 128)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 64, 64, 128)  147456      spatial_dropout2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 64, 64, 128)  512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 128)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 256)  294912      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 32, 32, 256)  1024        conv2d_8[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_4 (SpatialDro (None, 32, 32, 256)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 256)  589824      spatial_dropout2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 32, 32, 256)  1024        conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 64, 64, 128)  131200      batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 64, 64, 128)  16512       batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 64, 64, 128)  16512       conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 64, 64, 128)  0           conv2d_10[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 64, 64, 128)  0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 64, 64, 1)    129         activation[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 64, 64, 1)    0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 64, 64, 128)  0           batch_normalization_7[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 64, 64, 256)  0           conv2d_transpose[0][0]
#                                                                  multiply[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 128)  294912      concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 64, 64, 128)  512         conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 128)  147456      batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 64, 64, 128)  512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 128, 128, 64) 32832       batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 128, 128, 64) 4160        batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 128, 128, 64) 4160        conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 128, 128, 64) 0           conv2d_15[0][0]
#                                                                  conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 128, 128, 64) 0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 128, 128, 1)  65          activation_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 128, 128, 1)  0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 128, 128, 64) 0           batch_normalization_5[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 128, 128, 128 0           conv2d_transpose_1[0][0]
#                                                                  multiply_1[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 128, 128, 64) 73728       concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 128, 128, 64) 256         conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 128, 128, 64) 36864       batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 128, 128, 64) 256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 256, 256, 32) 8224        batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 256, 256, 32) 1056        batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 256, 256, 32) 1056        conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 256, 256, 32) 0           conv2d_20[0][0]
#                                                                  conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 256, 256, 32) 0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 256, 256, 1)  33          activation_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 256, 256, 1)  0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 256, 256, 32) 0           batch_normalization_3[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 256, 256, 64) 0           conv2d_transpose_2[0][0]
#                                                                  multiply_2[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 256, 256, 32) 18432       concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 256, 256, 32) 128         conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 256, 256, 32) 9216        batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 256, 256, 32) 128         conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 512, 512, 16) 2064        batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 512, 512, 16) 272         batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 512, 512, 16) 272         conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 512, 512, 16) 0           conv2d_25[0][0]
#                                                                  conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 512, 512, 16) 0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 512, 512, 1)  17          activation_6[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 512, 512, 1)  0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 512, 512, 16) 0           batch_normalization_1[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 512, 512, 32) 0           conv2d_transpose_3[0][0]
#                                                                  multiply_3[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 512, 512, 16) 4608        concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 512, 512, 16) 64          conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 512, 512, 16) 2304        batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 512, 512, 16) 64          conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 512, 512, 1)  17          batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# tf.slice (TFOpLambda)           (None, 376, 257, 1)  0           conv2d_30[0][0]
# ==================================================================================================
# Total params: 1,990,197
# Trainable params: 1,987,253
# Non-trainable params: 2,944
# __________________________________________________________________________________________________

# %%
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
loss_fn = tf.keras.losses.MeanAbsoluteError(
    reduction="auto", name="mean_absolute_error"
)
def chunk_list(input_list, chunk_size):
    """Convert list into a list of lists."""
    return [
        input_list[chunk : chunk + chunk_size]
        for chunk in range(0, len(input_list), chunk_size)
    ]

checkpoint_filepath = Path('/home/kenders/greenhdd/clarity_challenge/pk_speech_enhancement/models')
if not checkpoint_filepath.exists():
    os.makedirs(checkpoint_filepath)

epochs = 20
sub_batch_size = 3

enq = tf.keras.utils.OrderedEnqueuer(data_loader, use_multiprocessing=False)
enq.start(workers=1)
gen = enq.get()

progbar = tf.keras.utils.Progbar(len(data_loader))

for epoch in range(epochs):
    print(f"epoch {epoch} \n")
    # model.save(checkpoint_filepath / f"{epoch}_start")
    # Iterate over the batches of the dataset.
    for batch_n in range(len(data_loader)):
        x_spec, y_spec = next(gen)
        # print(f"epoch {epoch} batch {batch_n} of {len(data_loader)}")
        # the batches are large and need to split into smaller chunks for feeding into the network
        x_spec, y_spec = sklearn.utils.shuffle(x_spec, y_spec)
        x_spec_chunked, y_spec_chunked = chunk_list(x_spec, sub_batch_size), chunk_list(y_spec, sub_batch_size)
        
        for sub_batch, (x_batch_train, y_batch_train) in enumerate(zip(x_spec_chunked, y_spec_chunked)):
            with tf.device('/gpu:0'):
                with tf.GradientTape() as tape:
                    logits = model(x_batch_train, training=True)  # Logits for this minibatch
                    # Compute the loss value for this minibatch.
                    loss_value = loss_fn(y_batch_train, logits)

                # Use the gradient tape to automatically retrieve
                # the gradients of the trainable variables with respect to the loss.
                grads = tape.gradient(loss_value, model.trainable_weights)

                # Run one step of gradient descent by updating
                # the value of the variables to minimize the loss.
                opt.apply_gradients(zip(grads, model.trainable_weights))
        progbar.add(1, values=[("loss", float(loss_value))])
    model.save(checkpoint_filepath / f"{epoch}_{float(loss_value):.4}")
# Out:
# epoch 0 batch 3 of 6000
#    1/6000 [..............................] - ETA: 48:23:24 - loss: 0.0402
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-f60733b0d8b4> in <module>
#      47                 # Run one step of gradient descent by updating
#      48                 # the value of the variables to minimize the loss.
# ---> 49                 opt.apply_gradients(zip(grads, model.trainable_weights))
#      50         progbar.add(1, values=[("loss", float(loss_value))])
#      51     model.save(checkpoint_filepath / f"{epoch}_{float(loss_value):.4}")
#
# ~/.virtualenvs/main/lib/python3.6/site-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py in apply_gradients(self, grads_and_vars, name, experimental_aggregate_gradients)
#     633           args=(grads_and_vars,),
#     634           kwargs={
# --> 635               "name": name,
#     636           })
#     637
#
# ~/.virtualenvs/main/lib/python3.6/site-packages/tensorflow/python/distribute/distribute_lib.py in merge_call(self, merge_fn, args, kwargs)
#    2939     merge_fn = autograph.tf_convert(
#    2940         merge_fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 2941     return self._merge_call(merge_fn, args, kwargs)
#    2942
#    2943   def _merge_call(self, merge_fn, args, kwargs):
#
# ~/.virtualenvs/main/lib/python3.6/site-packages/tensorflow/python/distribute/distribute_lib.py in _merge_call(self, merge_fn, args, kwargs)
#    2946         distribution_strategy_context._CrossReplicaThreadMode(self._strategy))  # pylint: disable=protected-access
#    2947     try:
# -> 2948       return merge_fn(self._strategy, *args, **kwargs)
#    2949     finally:
#    2950       _pop_per_thread_mode()
#
# ~/.virtualenvs/main/lib/python3.6/site-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     570   def wrapper(*args, **kwargs):
#     571     with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.UNSPECIFIED):
# --> 572       return func(*args, **kwargs)
#     573
#     574   if inspect.isfunction(func) or inspect.ismethod(func):
#
# ~/.virtualenvs/main/lib/python3.6/site-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py in _distributed_apply(self, distribution, grads_and_vars, name, apply_state)
#     681                               "update_" + var.op.name, skip_on_eager=True):
#     682             update_ops.extend(distribution.extended.update(
# --> 683                 var, apply_grad_to_update_var, args=(grad,), group=False))
#     684
#     685       any_symbolic = any(isinstance(i, ops.Operation) or
#
# ~/.virtualenvs/main/lib/python3.6/site-packages/tensorflow/python/distribute/distribute_lib.py in update(self, var, fn, args, kwargs, group)
#    2490       kwargs = {}
#    2491     fn = autograph.tf_convert(
# -> 2492         fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
#    2493     with self._container_strategy().scope():
#    2494       return self._update(var, fn, args, kwargs, group)
#
# ~/.virtualenvs/main/lib/python3.6/site-packages/tensorflow/python/autograph/impl/api.py in tf_convert(f, ctx, convert_by_default, user_requested)
#     558   else:
#     559     assert False, 'This switch contains all possible cases!'
# --> 560   wrapper = wrapper_factory(f)
#     561
#     562   if decorators:
#
# ~/.virtualenvs/main/lib/python3.6/site-packages/tensorflow/python/autograph/impl/api.py in call_with_unspecified_conversion_status(func)
#     573
#     574   if inspect.isfunction(func) or inspect.ismethod(func):
# --> 575     wrapper = functools.update_wrapper(wrapper, func)
#     576
#     577   return autograph_artifact(wrapper)
#
# /usr/lib/python3.6/functools.py in update_wrapper(wrapper, wrapped, assigned, updated)
#      63             pass
#      64         else:
# ---> 65             setattr(wrapper, attr, value)
#      66     for attr in updated:
#      67         getattr(wrapper, attr).update(getattr(wrapped, attr, {}))
#
# KeyboardInterrupt:

# %%
model.save(checkpoint_filepath / f"{epoch}_{float(loss_value):.4}")
# Out:
# INFO:tensorflow:Assets written to: /home/kenders/greenhdd/clarity_challenge/pk_speech_enhancement/models/0_0.0848/assets
# INFO:copy_assets_to_destination_dir: Assets written to: /home/kenders/greenhdd/clarity_challenge/pk_speech_enhancement/models/0_0.0848/assets
